# %%
import matplotlib.pyplot as plt
import numpy as np

vals_1 = np.sin(np.linspace(0,np.pi*2, 100))
vals_2 = np.cos(np.linspace(0,np.pi*2, 100))

plt.plot(vals_1, label = "Trivial Sin")
plt.plot(vals_2, label = "Trivial Cos")

plt.title("See, I can do it ;)")

plt.legend()


plt.show()
